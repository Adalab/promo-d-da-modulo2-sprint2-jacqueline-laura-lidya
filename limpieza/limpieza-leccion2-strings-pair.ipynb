# %% [markdown]
# # **Ejercicios de pair programming Módulo 2 Sprint 2**
# ## **Limpieza: Lección II**
# ### **Hipótesis**

# %% [markdown]
# 1. La edad, el trabajo, el estado civil, la educación, la situación de deuda y la forma de contacto pueden influir en la probabilidad de que un cliente acepte la oferta.
# 2. El número de veces que se ha contactado a un cliente en el pasado (campo campaign), el número de días que han pasado desde el último contacto (campo pdays), y el resultado de la campaña anterior (campo poutcome) pueden afectar la respuesta del cliente a una nueva oferta.
# 3. Las variables económicas (tales como el índice de precios al consumidor (cons.price.idx), la tasa de variación del empleo (emp.var.rate), etc.) pueden influir en la probabilidad de que un cliente acepte la oferta.
# 4. Los clientes que ya tienen una hipoteca (housing) o un préstamo (loan) pueden ser menos propensos a aceptar una nueva oferta, ya que podrían estar limitados financieramente.
# Por lo tanto, en este ejercicio nos queda por limpiar algunas columnas del conjunto de datos, así que manos a la obra. Vamos a ver que podemos hacer para cada una de las columnas y os dejaremos algunas pistas 😉. Para esto trabajaremos con el fichero generado en Limpieza I.

# %% [markdown]
# 1. Columnas loan, housing y default: estas columnas contienen valores únicos de 0 y 1. Esto puede parecer poco intuitivo a la hora de la extracción de conclusiones y en las visualizaciones. El objetivo de este ejercicio es que cambies los valores númericos por "Si" y "No". A que corresponde cada uno de los valores lo tenéis en el pair de Limpieza I.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df_bank = pd.read_csv("data/bank-additional-full-procesado.csv", index_col = 0)

# %%
mapa = {1.0: "Sí", 0.0: "No"}
for col in df_bank.columns[4:7]:
       df_bank[col] = df_bank[col].map(mapa, na_action = "ignore")
df_bank
# Out:
#        age          job  marital            education default housing loan  \
# 0       56    housemaid  married             basic.4y      No      No   No
# 1       57     services  married          high.school     NaN      No   No
# 2       37     services  married          high.school      No      Sí   No
# 3       40       admin.  married             basic.6y      No      No   No
# 4       56     services  married          high.school      No      No   Sí
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41183   73      retired  married  professional.course      No      Sí   No
# 41184   46  blue-collar  married  professional.course      No      No   No
# 41185   56      retired  married    university.degree      No      Sí   No
# 41186   44   technician  married  professional.course      No      No   No
# 41187   74      retired  married  professional.course      No      Sí   No
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 0      telephone       261         1    999         0  NONEXISTENT
# 1      telephone       149         1    999         0  NONEXISTENT
# 2      telephone       226         1    999         0  NONEXISTENT
# 3      telephone       151         1    999         0  NONEXISTENT
# 4      telephone       307         1    999         0  NONEXISTENT
# ...          ...       ...       ...    ...       ...          ...
# 41183   cellular       334         1    999         0  NONEXISTENT
# 41184   cellular       383         1    999         0  NONEXISTENT
# 41185   cellular       189         2    999         0  NONEXISTENT
# 41186   cellular       442         1    999         0  NONEXISTENT
# 41187   cellular       239         3    999         1      FAILURE
#
#        emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  nr,employed  \
# 0               1.1          93.994          -36.4      4.857       5191.0
# 1               1.1          93.994          -36.4      4.857       5191.0
# 2               1.1          93.994          -36.4      4.857       5191.0
# 3               1.1          93.994          -36.4      4.857       5191.0
# 4               1.1          93.994          -36.4      4.857       5191.0
# ...             ...             ...            ...        ...          ...
# 41183          -1.1          94.767          -50.8      1.028       4963.6
# 41184          -1.1          94.767          -50.8      1.028       4963.6
# 41185          -1.1          94.767          -50.8      1.028       4963.6
# 41186          -1.1          94.767          -50.8      1.028       4963.6
# 41187          -1.1          94.767          -50.8      1.028       4963.6
#
#          y  month_day_week
# 0       no  ['may', 'mon']
# 1       no  ['may', 'mon']
# 2       no  ['may', 'mon']
# 3       no  ['may', 'mon']
# 4       no  ['may', 'mon']
# ...    ...             ...
# 41183  yes  ['nov', 'fri']
# 41184   no  ['nov', 'fri']
# 41185   no  ['nov', 'fri']
# 41186  yes  ['nov', 'fri']
# 41187   no  ['nov', 'fri']
#
# [41176 rows x 20 columns]

# %% [markdown]
# 2. Para la columna de education, si nos fijamos en sus valores únicos veremos que tenemos puntos. El objetivo de este ejercicio es que quitéis los puntos de esos valores y los reemplacéis por espacios.

# %%
def punto_espacio(col):
    try:
        return col.replace("."," ")
    except:
        return col

# %%
df_bank["education"]=df_bank["education"].apply(punto_espacio)
df_bank.head(10)
# Out:
#    age          job  marital            education default housing loan  \
# 0   56    housemaid  married             basic 4y      No      No   No
# 1   57     services  married          high school     NaN      No   No
# 2   37     services  married          high school      No      Sí   No
# 3   40       admin.  married             basic 6y      No      No   No
# 4   56     services  married          high school      No      No   Sí
# 5   45     services  married             basic 9y     NaN      No   No
# 6   59       admin.  married  professional course      No      No   No
# 7   41  blue-collar  married                  NaN     NaN      No   No
# 8   24   technician   single  professional course      No      Sí   No
# 9   25     services   single          high school      No      Sí   No
#
#      contact  duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0  telephone       261         1    999         0  NONEXISTENT           1.1
# 1  telephone       149         1    999         0  NONEXISTENT           1.1
# 2  telephone       226         1    999         0  NONEXISTENT           1.1
# 3  telephone       151         1    999         0  NONEXISTENT           1.1
# 4  telephone       307         1    999         0  NONEXISTENT           1.1
# 5  telephone       198         1    999         0  NONEXISTENT           1.1
# 6  telephone       139         1    999         0  NONEXISTENT           1.1
# 7  telephone       217         1    999         0  NONEXISTENT           1.1
# 8  telephone       380         1    999         0  NONEXISTENT           1.1
# 9  telephone        50         1    999         0  NONEXISTENT           1.1
#
#    cons,price,idx  cons,conf,idx  euribor3m  nr,employed   y  month_day_week
# 0          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 1          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 2          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 3          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 4          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 5          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 6          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 7          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 8          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 9          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']

# %% [markdown]
# 3. Para la columna job, hay un valor único que esta abreviado (admin.), cambiad la abreviatura por el nombre completo.

# %%
def completo(col):
    try:
        return col.replace("admin.","administration")
    except:
        return col

# %%
df_bank["job"]=df_bank["job"].apply(completo)
df_bank.head(10)
# Out:
#    age             job  marital            education default housing loan  \
# 0   56       housemaid  married             basic 4y      No      No   No
# 1   57        services  married          high school     NaN      No   No
# 2   37        services  married          high school      No      Sí   No
# 3   40  administration  married             basic 6y      No      No   No
# 4   56        services  married          high school      No      No   Sí
# 5   45        services  married             basic 9y     NaN      No   No
# 6   59  administration  married  professional course      No      No   No
# 7   41     blue-collar  married                  NaN     NaN      No   No
# 8   24      technician   single  professional course      No      Sí   No
# 9   25        services   single          high school      No      Sí   No
#
#      contact  duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0  telephone       261         1    999         0  NONEXISTENT           1.1
# 1  telephone       149         1    999         0  NONEXISTENT           1.1
# 2  telephone       226         1    999         0  NONEXISTENT           1.1
# 3  telephone       151         1    999         0  NONEXISTENT           1.1
# 4  telephone       307         1    999         0  NONEXISTENT           1.1
# 5  telephone       198         1    999         0  NONEXISTENT           1.1
# 6  telephone       139         1    999         0  NONEXISTENT           1.1
# 7  telephone       217         1    999         0  NONEXISTENT           1.1
# 8  telephone       380         1    999         0  NONEXISTENT           1.1
# 9  telephone        50         1    999         0  NONEXISTENT           1.1
#
#    cons,price,idx  cons,conf,idx  euribor3m  nr,employed   y  month_day_week
# 0          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 1          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 2          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 3          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 4          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 5          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 6          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 7          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 8          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 9          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']

# %% [markdown]
# 4. La columna month_day_week tiene una lista que contiene información muy diferente. El objetivo de este ejercicio es separar esta columna en dos nuevas, donde tengamos los meses en una columna y los días de la semana en otra.

# %%
df_bank[['month', 'day']] = df_bank['month_day_week'].str.split(', ' ,expand = True, n = 1)
df_bank.head(3)
# Out:
#    age        job  marital    education default housing loan    contact  \
# 0   56  housemaid  married     basic 4y      No      No   No  telephone
# 1   57   services  married  high school     NaN      No   No  telephone
# 2   37   services  married  high school      No      Sí   No  telephone
#
#    duration  campaign  ...     poutcome  emp,var,rate cons,price,idx  \
# 0       261         1  ...  NONEXISTENT           1.1         93.994
# 1       149         1  ...  NONEXISTENT           1.1         93.994
# 2       226         1  ...  NONEXISTENT           1.1         93.994
#
#    cons,conf,idx  euribor3m  nr,employed   y  month_day_week   month     day
# 0          -36.4      4.857       5191.0  no  ['may', 'mon']  ['may'  'mon']
# 1          -36.4      4.857       5191.0  no  ['may', 'mon']  ['may'  'mon']
# 2          -36.4      4.857       5191.0  no  ['may', 'mon']  ['may'  'mon']
#
# [3 rows x 22 columns]

# %%
#aunque el método split nos ha separado las columnas, nos ha mantenido los corchetes. DEcidimos aplicar un replace para eliminarlos.
def fecha (col):
    try:
        return col.replace("[","").replace("]","")
    except:
        return col

# %%
df_bank["month"]=df_bank["month"].apply(fecha)
df_bank["day"]=df_bank["day"].apply(fecha)
df_bank.head(10)
# Out:
#    age             job  marital            education default housing loan  \
# 0   56       housemaid  married             basic 4y      No      No   No
# 1   57        services  married          high school     NaN      No   No
# 2   37        services  married          high school      No      Sí   No
# 3   40  administration  married             basic 6y      No      No   No
# 4   56        services  married          high school      No      No   Sí
# 5   45        services  married             basic 9y     NaN      No   No
# 6   59  administration  married  professional course      No      No   No
# 7   41     blue-collar  married                  NaN     NaN      No   No
# 8   24      technician   single  professional course      No      Sí   No
# 9   25        services   single          high school      No      Sí   No
#
#      contact  duration  campaign  ...     poutcome  emp,var,rate  \
# 0  telephone       261         1  ...  NONEXISTENT           1.1
# 1  telephone       149         1  ...  NONEXISTENT           1.1
# 2  telephone       226         1  ...  NONEXISTENT           1.1
# 3  telephone       151         1  ...  NONEXISTENT           1.1
# 4  telephone       307         1  ...  NONEXISTENT           1.1
# 5  telephone       198         1  ...  NONEXISTENT           1.1
# 6  telephone       139         1  ...  NONEXISTENT           1.1
# 7  telephone       217         1  ...  NONEXISTENT           1.1
# 8  telephone       380         1  ...  NONEXISTENT           1.1
# 9  telephone        50         1  ...  NONEXISTENT           1.1
#
#   cons,price,idx  cons,conf,idx  euribor3m  nr,employed   y  month_day_week  \
# 0         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 1         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 2         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 3         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 4         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 5         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 6         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 7         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 8         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 9         93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
#
#    month    day
# 0  'may'  'mon'
# 1  'may'  'mon'
# 2  'may'  'mon'
# 3  'may'  'mon'
# 4  'may'  'mon'
# 5  'may'  'mon'
# 6  'may'  'mon'
# 7  'may'  'mon'
# 8  'may'  'mon'
# 9  'may'  'mon'
#
# [10 rows x 22 columns]

# %% [markdown]
# 5. Guarda el csv con las columnas limpias para seguir trabajando con este dataframe limpio.

# %%
df_bank.to_csv("data/bank-additional-full-procesado2.csv")
