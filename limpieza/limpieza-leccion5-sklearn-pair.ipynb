# %% [markdown]
# # **Ejercicios de pair programming Módulo 2 Sprint 2**
# ## **Limpieza: Lección 5**
# ### **Valores nulos: Sklearn**
#
# ---

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer 
from sklearn.impute import KNNImputer

# %%
df_bank = pd.read_csv("data/bank-additional-full-procesado3.csv", index_col = 0)

# %%
df_bank.sample(3)
# Out:
#        age             job  marital          education default housing loan  \
# 19801   56       housemaid  married           basic 4y     NaN      No   No
# 2028    36    entrepreneur  married  university degree      No      Sí   No
# 24465   42  administration  married  university degree      No      Sí   No
#
#          contact  duration  campaign  ...     poutcome  emp,var,rate  \
# 19801   cellular        87         1  ...  NONEXISTENT           1.4
# 2028   telephone        59         4  ...  NONEXISTENT           1.1
# 24465   cellular       120         1  ...  NONEXISTENT          -0.1
#
#       cons,price,idx  cons,conf,idx  euribor3m  nr,employed   y  \
# 19801         93.444          -36.1      4.966       5228.1  no
# 2028          93.994          -36.4      4.857       5191.0  no
# 24465         93.200          -42.0      4.191       5195.8  no
#
#        month_day_week  month    day
# 19801  ['aug', 'fri']  'aug'  'fri'
# 2028   ['may', 'mon']  'may'  'mon'
# 24465  ['nov', 'mon']  'nov'  'mon'
#
# [3 rows x 22 columns]

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41176 entries, 0 to 41187
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             40846 non-null  object
#  2   marital         41096 non-null  object
#  3   education       39446 non-null  object
#  4   default         32580 non-null  object
#  5   housing         40186 non-null  object
#  6   loan            40186 non-null  object
#  7   contact         41176 non-null  object
#  8   duration        41176 non-null  int64
#  9   campaign        41176 non-null  int64
#  10  pdays           41176 non-null  int64
#  11  previous        41176 non-null  int64
#  12  poutcome        41176 non-null  object
#  13  emp,var,rate    41176 non-null  float64
#  14  cons,price,idx  41176 non-null  float64
#  15  cons,conf,idx   41176 non-null  float64
#  16  euribor3m       41176 non-null  float64
#  17  nr,employed     41176 non-null  float64
#  18  y               41176 non-null  object
#  19  month_day_week  41176 non-null  object
#  20  month           41176 non-null  object
#  21  day             41176 non-null  object
# dtypes: float64(5), int64(5), object(12)
# memory usage: 7.2+ MB

# %% [markdown]
# 1. Es el momento de eliminar los nulos:
# - Reemplazad los valores nulos del resto de las columnas categóricas por la moda, usando el método SimpleImputer.
# 💡 Pista 💡 La moda en este tipo de aproximación se indica como most_frequent.

# %%
df_categoricas = df_bank.select_dtypes(include= 'object')

df_categoricas
# Out:
#                   job  marital            education default housing loan  \
# 0           housemaid  married             basic 4y      No      No   No
# 1            services  married          high school     NaN      No   No
# 2            services  married          high school      No      Sí   No
# 3      administration  married             basic 6y      No      No   No
# 4            services  married          high school      No      No   Sí
# ...               ...      ...                  ...     ...     ...  ...
# 41183         retired  married  professional course      No      Sí   No
# 41184     blue-collar  married  professional course      No      No   No
# 41185         retired  married    university degree      No      Sí   No
# 41186      technician  married  professional course      No      No   No
# 41187         retired  married  professional course      No      Sí   No
#
#          contact     poutcome    y  month_day_week  month    day
# 0      telephone  NONEXISTENT   no  ['may', 'mon']  'may'  'mon'
# 1      telephone  NONEXISTENT   no  ['may', 'mon']  'may'  'mon'
# 2      telephone  NONEXISTENT   no  ['may', 'mon']  'may'  'mon'
# 3      telephone  NONEXISTENT   no  ['may', 'mon']  'may'  'mon'
# 4      telephone  NONEXISTENT   no  ['may', 'mon']  'may'  'mon'
# ...          ...          ...  ...             ...    ...    ...
# 41183   cellular  NONEXISTENT  yes  ['nov', 'fri']  'nov'  'fri'
# 41184   cellular  NONEXISTENT   no  ['nov', 'fri']  'nov'  'fri'
# 41185   cellular  NONEXISTENT   no  ['nov', 'fri']  'nov'  'fri'
# 41186   cellular  NONEXISTENT  yes  ['nov', 'fri']  'nov'  'fri'
# 41187   cellular      FAILURE   no  ['nov', 'fri']  'nov'  'fri'
#
# [41176 rows x 12 columns]

# %%
imputer = SimpleImputer(strategy= 'most_frequent', missing_values= np.nan)
imputer = imputer.fit(df_categoricas)

# %%
df_categoricas[['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
       'poutcome', 'y', 'month_day_week', 'month', 'day']] = imputer.transform(df_categoricas[['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
       'poutcome', 'y', 'month_day_week', 'month', 'day']])

# %%
df_categoricas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41176 entries, 0 to 41187
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   job             41176 non-null  object
#  1   marital         41176 non-null  object
#  2   education       41176 non-null  object
#  3   default         41176 non-null  object
#  4   housing         41176 non-null  object
#  5   loan            41176 non-null  object
#  6   contact         41176 non-null  object
#  7   poutcome        41176 non-null  object
#  8   y               41176 non-null  object
#  9   month_day_week  41176 non-null  object
#  10  month           41176 non-null  object
#  11  day             41176 non-null  object
# dtypes: object(12)
# memory usage: 4.1+ MB

# %%
columnas = df_categoricas.columns
df_bank.drop(columnas, axis= 1, inplace= True)
df_bank[columnas] = df_categoricas[columnas]

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41176 entries, 0 to 41187
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   duration        41176 non-null  int64
#  2   campaign        41176 non-null  int64
#  3   pdays           41176 non-null  int64
#  4   previous        41176 non-null  int64
#  5   emp,var,rate    41176 non-null  float64
#  6   cons,price,idx  41176 non-null  float64
#  7   cons,conf,idx   41176 non-null  float64
#  8   euribor3m       41176 non-null  float64
#  9   nr,employed     41176 non-null  float64
#  10  job             41176 non-null  object
#  11  marital         41176 non-null  object
#  12  education       41176 non-null  object
#  13  default         41176 non-null  object
#  14  housing         41176 non-null  object
#  15  loan            41176 non-null  object
#  16  contact         41176 non-null  object
#  17  poutcome        41176 non-null  object
#  18  y               41176 non-null  object
#  19  month_day_week  41176 non-null  object
#  20  month           41176 non-null  object
#  21  day             41176 non-null  object
# dtypes: float64(5), int64(5), object(12)
# memory usage: 7.2+ MB

# %% [markdown]
# - Utilizad el método Iterative Imputer para reemplazar todos los valores nulos de las columnas numéricas.

# %%
df_numericas = df_bank.select_dtypes(include= np.number)

df_numericas
# Out:
#        age  duration  campaign  pdays  previous  emp,var,rate  cons,price,idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
#        cons,conf,idx  euribor3m  nr,employed
# 0              -36.4      4.857       5191.0
# 1              -36.4      4.857       5191.0
# 2              -36.4      4.857       5191.0
# 3              -36.4      4.857       5191.0
# 4              -36.4      4.857       5191.0
# ...              ...        ...          ...
# 41183          -50.8      1.028       4963.6
# 41184          -50.8      1.028       4963.6
# 41185          -50.8      1.028       4963.6
# 41186          -50.8      1.028       4963.6
# 41187          -50.8      1.028       4963.6
#
# [41176 rows x 10 columns]

# %%
df_numericas.columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp,var,rate',
#        'cons,price,idx', 'cons,conf,idx', 'euribor3m', 'nr,employed'],
#       dtype='object')

# %%
imputer = IterativeImputer(n_nearest_features= None, imputation_order= 'ascending')
imputer = imputer.fit(df_numericas)

df_num_trans = pd.DataFrame(imputer.transform(df_numericas), columns= df_numericas.columns)

# %%
columnas_num = df_numericas.columns
df_bank.drop(columnas_num, axis= 1, inplace= True)
df_bank[columnas_num] = df_numericas[columnas_num]

# %% [markdown]
# - Reemplazad los valores nulos de la columna age por la media de la edad usando el método KNN Imputer.

# %%
imputerKNN_age = KNNImputer(n_neighbors=5)
imputerKNN_age.fit(df_bank['age'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 imputerKNN_age = KNNImputer(n_neighbors=5)
# ----> 2 imputerKNN_age.fit(df_bank['age'])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/impute/_knn.py:226, in KNNImputer.fit(self, X, y)
#     223 else:
#     224     force_all_finite = "allow-nan"
# --> 226 X = self._validate_data(
#     227     X,
#     228     accept_sparse=False,
#     229     dtype=FLOAT_DTYPES,
#     230     force_all_finite=force_all_finite,
#     231     copy=self.copy,
#     232 )
#     234 self._fit_X = X
#     235 self._mask_fit_X = _get_mask(self._fit_X, self.missing_values)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:902, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     900     # If input is 1D raise error
#     901     if array.ndim == 1:
# --> 902         raise ValueError(
#     903             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     904             "Reshape your data either using array.reshape(-1, 1) if "
#     905             "your data has a single feature or array.reshape(1, -1) "
#     906             "if it contains a single sample.".format(array)
#     907         )
#     909 if dtype_numeric and array.dtype.kind in "USV":
#     910     raise ValueError(
#     911         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     912         "Convert your data to numeric values explicitly instead."
#     913     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[56. 57. 37. ... 56. 44. 74.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
array_age

# %% [markdown]
# - Reemplazad los valores nulos de la columna age por la media de la edad usando el método Simple Imputer.

# %% [markdown]
# - ¿Podríais explicar qué diferencia hay entre estos últimos tres ejercicios?

# %% [markdown]
# 2. Guardad el csv.
