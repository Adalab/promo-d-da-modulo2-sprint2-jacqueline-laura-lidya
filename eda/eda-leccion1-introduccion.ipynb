# %% [markdown]
# # **Ejercicios de pair programming Módulo 2 Sprint 2**
# ## **EDA: Lección 1**
# ### **Introducción**
#
# ---

# %%
import pandas as pd

# %%
df_tickets = pd.read_csv("data/historico_tickets_limpio.csv", index_col = 0)
pd.options.display.max_columns = None

# %% [markdown]
# ### **IMPORTANTE**
#
# **Estos ejercicios son complementarios a la información que viene en el gitbook. Hay que revisar primero el texto de las hipótesis antes de iniciar la resolución de ejercicios.**

# %% [markdown]
# 1. Haced una exploración inicial del dataframe:
# - ¿Cuál es el número de filas y columnas?

# %%
print(f"El dataframe tiene {df_tickets.shape[0]} filas y {df_tickets.shape[1]} columnas.")
# Out:
# El dataframe tiene 97386 filas y 13 columnas.

# %% [markdown]
# - ¿Cuál es el porcentaje de valores nulos en cada columna? Presenta los resultados en un dataframe, donde las columnas sean el nombre de las variables y el porcentaje de nulos.

# %%
df_porcentaje_nulos = pd.DataFrame(df_tickets.isnull().sum()/df_tickets.shape[0]*100)
df_porcentaje_nulos
# Out:
#                    0
# id_ticket        0.0
# fecha            0.0
# id_empleado      0.0
# id_agente        0.0
# categoría        0.0
# tipo             0.0
# severidad        0.0
# prioridad        0.0
# días_resolución  0.0
# satisfacción     0.0
# semestre         0.0
# año              0.0
# mes              0.0

# %% [markdown]
# - ¿Qué tipos de datos hay en cada columna?

# %%
df_tickets.dtypes
# Out:
# id_ticket          object
# fecha              object
# id_empleado         int64
# id_agente           int64
# categoría          object
# tipo               object
# severidad          object
# prioridad          object
# días_resolución     int64
# satisfacción        int64
# semestre           object
# año                 int64
# mes                object
# dtype: object

# %% [markdown]
# - Extraed la información general del dataframe.

# %%
df_tickets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97386 entries, 0 to 29087
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_ticket        97386 non-null  object
#  1   fecha            97386 non-null  object
#  2   id_empleado      97386 non-null  int64
#  3   id_agente        97386 non-null  int64
#  4   categoría        97386 non-null  object
#  5   tipo             97386 non-null  object
#  6   severidad        97386 non-null  object
#  7   prioridad        97386 non-null  object
#  8   días_resolución  97386 non-null  int64
#  9   satisfacción     97386 non-null  int64
#  10  semestre         97386 non-null  object
#  11  año              97386 non-null  int64
#  12  mes              97386 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 10.4+ MB

# %% [markdown]
# 2. Cread dos dataframes nuevos, uno que incluya solo las variables categóricas y otro que incluya solo las variables numéricas.

# %%
df_categoricas = df_tickets.select_dtypes(include = "object")
df_categoricas
# Out:
#                id_ticket       fecha     categoría       tipo  \
# 0      GDDENR-5042564453  2016-07-13  Acceso/Login   Problema
# 1      GDDENR-8042508060  2016-05-18  Acceso/Login   Problema
# 2      GDDESR-1342539995  2016-06-18       Sistema   Problema
# 3      GDDTSR-5942488006  2016-04-28       Sistema  Solicitud
# 4      GDLEER-0042524120  2016-06-03      Software   Problema
# ...                  ...         ...           ...        ...
# 29083  TWRTSR-8543883120  2020-02-22       Sistema  Solicitud
# 29084  TWRTSR-8744097039  2020-09-23       Sistema  Solicitud
# 29085  TWRTSR-9643846768  2020-01-16       Sistema  Solicitud
# 29086  TWRTSR-9944138906  2020-11-03       Sistema  Solicitud
# 29087  TWRTST-8643986162  2020-06-04       Sistema  Solicitud
#
#                 severidad        prioridad     semestre         mes
# 0      0 - Sin Clasificar  0 - Sin Asignar  2º semestre       Julio
# 1      0 - Sin Clasificar  0 - Sin Asignar   1 semestre        Mayo
# 2      0 - Sin Clasificar  0 - Sin Asignar   1 semestre       Junio
# 3      0 - Sin Clasificar  0 - Sin Asignar   1 semestre       Abril
# 4              2 - Normal  0 - Sin Asignar   1 semestre       Junio
# ...                   ...              ...          ...         ...
# 29083           3 - Mayor         1 - Baja   1 semestre     Febrero
# 29084           1 - Menor         1 - Baja  2º semestre  Septiembre
# 29085           3 - Mayor         1 - Baja   1 semestre       Enero
# 29086           1 - Menor         1 - Baja  2º semestre   Noviembre
# 29087           1 - Menor         1 - Baja   1 semestre       Junio
#
# [97386 rows x 8 columns]

# %%
df_numericas = df_tickets.select_dtypes(exclude = "object")
df_numericas
#¿Cómo sacaríamos este df con el parámetro include si el df tuviera variables de tipo float e int?
# Out:
#        id_empleado  id_agente  días_resolución  satisfacción   año
# 0             1735          4                0             5  2016
# 1             1566         10                0             5  2016
# 2              569         29                3             5  2016
# 3              320         40                9             5  2016
# 4             1842         31                0             5  2016
# ...            ...        ...              ...           ...   ...
# 29083         1142          1               11             5  2020
# 29084          223         40                7             4  2020
# 29085          256          7               13             5  2020
# 29086         1060          9                9             5  2020
# 29087         1876         41                6             4  2020
#
# [97386 rows x 5 columns]

# %% [markdown]
#  - ¿Cuáles son los principales estádisticos de los dataframes?

# %%
df_tickets.describe().T
# Out:
#                    count         mean         std     min     25%     50%  \
# id_empleado      97386.0   999.160639  577.407222     1.0   500.0   999.0
# id_agente        97386.0    25.468856   14.449455     1.0    13.0    26.0
# días_resolución  97386.0     4.552749    4.365432     0.0     0.0     4.0
# satisfacción     97386.0     4.100990    1.257093     1.0     4.0     5.0
# año              97386.0  2018.399164    1.393095  2016.0  2017.0  2019.0
#
#                     75%     max
# id_empleado      1499.0  2000.0
# id_agente          38.0    50.0
# días_resolución     7.0    21.0
# satisfacción        5.0     5.0
# año              2020.0  2020.0

# %%
df_tickets.describe(include = "object").T
# Out:
#            count unique                top   freq
# id_ticket  97386  97386  GDDENR-5042564453      1
# fecha      97386   1827         2020-02-20    105
# categoría  97386      4            Sistema  38961
# tipo       97386      2          Solicitud  73138
# severidad  97386      5         2 - Normal  88555
# prioridad  97386      4           3 - Alta  35511
# semestre   97386      2        2º semestre  49876
# mes        97386     12            Octubre   8487

# %% [markdown]
#  - Extraed los valores únicos.

# %%
for col in df_tickets.columns:
    print("---", "\n")
    print(f"La columna {col} tiene los siguientes valores únicos:")
    print(pd.DataFrame(df_tickets[col].value_counts()))
# Out:
# ---
#
# La columna id_ticket tiene los siguientes valores únicos:
#                    id_ticket
# GDDENR-5042564453          1
# TDLTSR-7643684027          1
# TDLTSR-7943733018          1
# TDLTSR-7943531091          1
# TDLTSR-7843654041          1
# ...                      ...
# GMLTSR-7943266311          1
# GMLTSR-7743345530          1
# GMLTSR-7743273810          1
# GMLTSR-7743134581          1
# TWRTST-8643986162          1
#
# [97386 rows x 1 columns]
# ---
#
# La columna fecha tiene los siguientes valores únicos:
#             fecha
# 2020-02-20    105
# 2020-12-16    105
# 2020-12-31    103
# 2020-03-14    103
# 2020-06-14    102
# ...           ...
# 2016-08-21     22
# 2016-03-04     22
# 2016-04-14     21
# 2016-07-08     18
# 2016-11-17     17
#
# [1827 rows x 1 columns]
# ---
#
# La columna id_empleado tiene los siguientes valores únicos:
#       id_empleado
# 285            73
# 754            73
# 636            71
# 523            69
# 1341           69
# ...           ...
# 1618           31
# 72             31
# 1195           29
# 99             27
# 793            26
#
# [2000 rows x 1 columns]
# ---
#
# La columna id_agente tiene los siguientes valores únicos:
#     id_agente
# 48       2026
# 39       2024
# 3        2019
# 35       2006
# 24       2002
# 5        1999
# 15       1990
# 4        1987
# 31       1985
# 19       1980
# 10       1972
# 32       1971
# 2        1966
# 27       1965
# 1        1964
# 41       1963
# 30       1962
# 26       1961
# 22       1961
# 17       1959
# 8        1957
# 33       1957
# 11       1951
# 6        1947
# 46       1947
# 9        1946
# 50       1945
# 28       1945
# 42       1943
# 44       1940
# 14       1939
# 38       1935
# 7        1933
# 47       1929
# 37       1929
# 29       1928
# 34       1927
# 45       1927
# 16       1923
# 20       1917
# 40       1917
# 23       1911
# 36       1911
# 25       1904
# 12       1896
# 43       1896
# 49       1890
# 18       1889
# 21       1889
# 13       1856
# ---
#
# La columna categoría tiene los siguientes valores únicos:
#               categoría
# Sistema           38961
# Acceso/Login      29165
# Software          19543
# Hardware           9717
# ---
#
# La columna tipo tiene los siguientes valores únicos:
#             tipo
# Solicitud  73138
# Problema   24248
# ---
#
# La columna severidad tiene los siguientes valores únicos:
#                     severidad
# 2 - Normal              88555
# 3 - Mayor                4831
# 1 - Menor                2254
# 4 - Crítico              1390
# 0 - Sin Clasificar        356
# ---
#
# La columna prioridad tiene los siguientes valores únicos:
#                  prioridad
# 3 - Alta             35511
# 0 - Sin Asignar      29376
# 1 - Baja             16670
# 2 - Media            15829
# ---
#
# La columna días_resolución tiene los siguientes valores únicos:
#     días_resolución
# 0             25049
# 1              9267
# 5              8779
# 6              7793
# 7              6578
# 2              6454
# 3              6194
# 4              4911
# 8              4841
# 10             3895
# 9              3732
# 11             1729
# 13             1711
# 14             1566
# 12             1555
# 15             1357
# 16             1165
# 17              553
# 19              130
# 18              123
# 21                2
# 20                2
# ---
#
# La columna satisfacción tiene los siguientes valores únicos:
#    satisfacción
# 5         50722
# 4         27529
# 1          9888
# 3          7271
# 2          1976
# ---
#
# La columna semestre tiene los siguientes valores únicos:
#              semestre
# 2º semestre     49876
# 1 semestre      47510
# ---
#
# La columna año tiene los siguientes valores únicos:
#         año
# 2020  29088
# 2019  21490
# 2018  18954
# 2017  14915
# 2016  12939
# ---
#
# La columna mes tiene los siguientes valores únicos:
#              mes
# Octubre     8487
# Agosto      8474
# Diciembre   8392
# Noviembre   8248
# Marzo       8219
# Septiembre  8210
# Junio       8131
# Mayo        8108
# Julio       8065
# Abril       7929
# Febrero     7892
# Enero       7231

# %%
for col in df_tickets.columns:
    print("---", "\n")
    print(f"La columna {col} tiene los siguientes valores únicos por cada columna:")
    print(df_tickets[col].unique())
# Out:
# ---
#
# La columna id_ticket tiene los siguientes valores únicos:
# ['GDDENR-5042564453' 'GDDENR-8042508060' 'GDDESR-1342539995' ...
#  'TWRTSR-9643846768' 'TWRTSR-9944138906' 'TWRTST-8643986162']
# ---
#
# La columna fecha tiene los siguientes valores únicos:
# ['2016-07-13' '2016-05-18' '2016-06-18' ... '2020-06-03' '2020-06-12'
#  '2020-02-19']
# ---
#
# La columna id_empleado tiene los siguientes valores únicos:
# [1735 1566  569 ... 1528 1367 1600]
# ---
#
# La columna id_agente tiene los siguientes valores únicos:
# [ 4 10 29 40 31 20 36 18 12 42  5 21 17  2 24 23 15 46 43 27  8 45 32 38
#  33 41  3  9 25 39 16 47 14 48 37 35 34 28 30  1 11 19 44  6 26 49  7 22
#  50 13]
# ---
#
# La columna categoría tiene los siguientes valores únicos:
# ['Acceso/Login' 'Sistema' 'Software' 'Hardware']
# ---
#
# La columna tipo tiene los siguientes valores únicos:
# ['Problema' 'Solicitud']
# ---
#
# La columna severidad tiene los siguientes valores únicos:
# ['0 - Sin Clasificar' '2 - Normal' '4 - Crítico' '3 - Mayor' '1 - Menor']
# ---
#
# La columna prioridad tiene los siguientes valores únicos:
# ['0 - Sin Asignar' '3 - Alta' '2 - Media' '1 - Baja']
# ---
#
# La columna días_resolución tiene los siguientes valores únicos:
# [ 0  3  9  1  2  5  8  4 10  6  7 13 16 17 11 12 14 15 19 18 21 20]
# ---
#
# La columna satisfacción tiene los siguientes valores únicos:
# [5 1 4 3 2]
# ---
#
# La columna semestre tiene los siguientes valores únicos:
# ['2º semestre' '1 semestre']
# ---
#
# La columna año tiene los siguientes valores únicos:
# [2016 2017 2018 2019 2020]
# ---
#
# La columna mes tiene los siguientes valores únicos:
# ['Julio' 'Mayo' 'Junio' 'Abril' 'Agosto' 'Marzo' 'Enero' 'Septiembre'
#  'Octubre' 'Diciembre' 'Noviembre' 'Febrero']

# %% [markdown]
# BONUS presenta los resultados en un dataframe. Os deberá quedar algo como esto:
#
# |variable|n_unicos|
# |--------|--------|
# |categoría|['Acceso/Login', 'Sistema', 'Software', 'Hardware', ...]|
# |tipo|['Problema', 'Solicitud', ...]|
# |semestre|['2º semestre', '1 semestre', ...]|
#
# Donde variable es cada una de las variables categóricas que tenemos en el dataset y n_unicos es una lista con los nombres de los valores únicos de cada variable.

# %%
dicc = {}
for col in df_tickets.columns:
        dicc.update({col : list(df_tickets[col].unique())})

print(dicc)

df_valores_unicos = pd.DataFrame(dicc)

#Hay que hacer un diccionario cuyas keys sean variable y n_unicos y cuyas values sean una lista de los nombres de las categorias y una lista de los uniques.
# Out:
# {'id_ticket': ['GDDENR-5042564453', 'GDDENR-8042508060', 'GDDESR-1342539995', 'GDDTSR-5942488006', 'GDLEER-0042524120', 'GDLEER-0142608095', 'GDLEER-0242564650', 'GDLEER-0542574815', 'GDLEER-0842457219', 'GDLEER-1242542213', 'GDLEER-1342611596', 'GDLEER-1442518153', 'GDLEER-2142385152', 'GDLEER-2342642781', 'GDLEER-2342666259', 'GDLEER-2342731423', 'GDLEER-2442674384', 'GDLEER-3042595564', 'GDLEER-3042628638', 'GDLEER-3042666351', 'GDLEER-3042712706', 'GDLEER-3042727271', 'GDLEER-3142699894', 'GDLEER-3242515550', 'GDLEER-3342606218', 'GDLEER-3542665966', 'GDLEER-3642442879', 'GDLEER-3742656857', 'GDLEER-4042683896', 'GDLEER-4342489822', 'GDLEER-4842380395', 'GDLEER-4942636742', 'GDLEER-5142678759', 'GDLEER-5242634706', 'GDLEER-5342415520', 'GDLEER-5542645174', 'GDLEER-5542655350', 'GDLEER-5642630998', 'GDLEER-5742437983', 'GDLEER-5842678281', 'GDLEER-6242606897', 'GDLEER-6342371191', 'GDLEER-6542472842', 'GDLEER-7242378136', 'GDLEER-7242415805', 'GDLEER-7342441622', 'GDLEER-7442377755', 'GDLEER-7542412443', 'GDLEER-7942651554', 'GDLEER-8242657344', 'GDLEER-9242649952', 'GDLEER-9342711505', 'GDLEET-1142646933', 'GDLEET-1342615230', 'GDLEET-3242634214', 'GDLEET-3642380865', 'GDLEET-4642626740', 'GDLEET-4642637748', 'GDLEET-5742695359', 'GDLEET-6142589667', 'GDLEET-6342503137', 'GDLEET-7542371023', 'GDLEET-7542513586', 'GDLEET-7742629769', 'GDLEET-7842705497', 'GDLEET-8142386963', 'GDLEET-8342380553', 'GDLEET-8742683735', 'GDLEET-8942397489', 'GDLEET-9142564081', 'GDLEET-9342397848', 'GDLEET-9542639332', 'GDLENR-0042442958', 'GDLENR-0042458396', 'GDLENR-1042392759', 'GDLENR-1042484815', 'GDLENR-1042487695', 'GDLENR-1042508223', 'GDLENR-1042665803', 'GDLENR-1042686934', 'GDLENR-1042706123', 'GDLENR-2042407414', 'GDLENR-2042589856', 'GDLENR-2042707447', 'GDLENR-2042723756', 'GDLENR-2142503103', 'GDLENR-3042406506', 'GDLENR-3042421854', 'GDLENR-3042434294', 'GDLENR-3042455761', 'GDLENR-3042547176', 'GDLENR-3042668609', 'GDLENR-3042686112', 'GDLENR-3142523579', 'GDLENR-4042373567', 'GDLENR-4042390443', 'GDLENR-4042563537', 'GDLENR-4042572365', 'GDLENR-4042625591', 'GDLENR-4042626020', 'GDLENR-4042668397', 'GDLENR-4042676763', 'GDLENR-4042698294', 'GDLENR-4042702792', 'GDLENR-4142431442', 'GDLENR-4142541882', 'GDLENR-4242537019', 'GDLENR-5042408558', 'GDLENR-5042423792', 'GDLENR-5042469459', 'GDLENR-5042538073', 'GDLENR-5042567651', 'GDLENR-5042593156', 'GDLENR-5042638718', 'GDLENR-5042701899', 'GDLENR-5042725925', 'GDLENR-5042730284', 'GDLENR-6042530747', 'GDLENR-6042536114', 'GDLENR-6042581955', 'GDLENR-6042655821', 'GDLENR-6042695293', 'GDLENR-6242639381', 'GDLENR-7042524573', 'GDLENR-7042572700', 'GDLENR-7042588109', 'GDLENR-7142578538', 'GDLENR-7142633175', 'GDLENR-7242484128', 'GDLENR-8042441618', 'GDLENR-8042464203', 'GDLENR-8042518947', 'GDLENR-8042534334', 'GDLENR-8042613653', 'GDLENR-8042673893', 'GDLENR-8142561329', 'GDLENR-8142639353', 'GDLENR-8142656861', 'GDLENR-9042389843', 'GDLENR-9042424141', 'GDLENR-9042494474', 'GDLENR-9042612728', 'GDLENR-9042629542', 'GDLENR-9042644411', 'GDLENR-9142441301', 'GDLENT-0042439967', 'GDLENT-1042585748', 'GDLENT-2042684721', 'GDLENT-2142503679', 'GDLENT-3042589848', 'GDLENT-3242491479', 'GDLENT-4042661806', 'GDLENT-5042707437', 'GDLENT-7042637176', 'GDLESR-0142497241', 'GDLESR-0142558772', 'GDLESR-0242517083', 'GDLESR-0342589729', 'GDLESR-0442561121', 'GDLESR-0542468918', 'GDLESR-0542610343', 'GDLESR-1142370492', 'GDLESR-1142419559', 'GDLESR-1142607144', 'GDLESR-1142676449', 'GDLESR-1242510942', 'GDLESR-1242548796', 'GDLESR-1242626550', 'GDLESR-1342452686', 'GDLESR-1442403807', 'GDLESR-1642411547', 'GDLESR-2142646426', 'GDLESR-2342648325', 'GDLESR-2442525904', 'GDLESR-2442625785', 'GDLESR-3142400257', 'GDLESR-3142425981', 'GDLESR-3142463818', 'GDLESR-3242521536', 'GDLESR-3342587629', 'GDLESR-3342676116', 'GDLESR-3442488474', 'GDLESR-3442687524', 'GDLESR-3542429105', 'GDLESR-3742460579', 'GDLESR-4142375562', 'GDLESR-4142504193', 'GDLESR-4242478503', 'GDLESR-4342443729', 'GDLESR-43426394 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /mnt/c/Users/lidya/Documents/Nuestros documentos/Documentos de Lidya/Estudios/Adalab/modulos/modulo2/pair_programming/promo-d-da-modulo2-sprint2-jacqueline-laura-lidya/eda/eda-leccion1-introduccion.ipynb Celda 23 in 7
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/c/Users/lidya/Documents/Nuestros%20documentos/Documentos%20de%20Lidya/Estudios/Adalab/modulos/modulo2/pair_programming/promo-d-da-modulo2-sprint2-jacqueline-laura-lidya/eda/eda-leccion1-introduccion.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>         dicc.update({col : list(df_tickets[col].unique())})
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/c/Users/lidya/Documents/Nuestros%20documentos/Documentos%20de%20Lidya/Estudios/Adalab/modulos/modulo2/pair_programming/promo-d-da-modulo2-sprint2-jacqueline-laura-lidya/eda/eda-leccion1-introduccion.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print(dicc)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/c/Users/lidya/Documents/Nuestros%20documentos/Documentos%20de%20Lidya/Estudios/Adalab/modulos/modulo2/pair_programming/promo-d-da-modulo2-sprint2-jacqueline-laura-lidya/eda/eda-leccion1-introduccion.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> df_valores_unicos = pd.DataFrame(dicc)
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# **Conclusiones**
#
# ¿De qué nos sirven estos números y dataframe? Extraed conclusiones de ellos.
#
# Por ejemplo:
#
# ¿Hay alguna columna que no tenga sentido su tipo de datos?
#
# ¿Hay alguna columna que no tenga sentido su nombre?
#
# ¿Hay alguna columna que no tenga sentido su contenido?
#
# ¿Hay alguna columna que tenga demasiadas categorías o valores que nos pueda hacer difícil trabajar con ella?
